# %% [markdown]
# # Objectives
#
# After completing this lab you will be able to:
#
# * Data types
#     * Numbers
#     * Strings
#     * Printing
#     * Lists
#     * Dictionaries
#     * Booleans
#     * Tuples
#     * Sets
# * Comparison Operators
# * Logical Operators
# * if, elif, else Statements
# ____

# %% [markdown]
# # Data types

# %%
# integer
number=10

# float
number2=10.5
number3=0.5

# string
strVar='Hossam'

#
char ='A'

# boolean
passing=False
flag2=True

# Empty value or null data type
none_var=None   # null

# Complex number
complex_num = 2 + 3j

# %%
name="Hossam"
age=26
flag=False
number=5.5
complex_num = 2 + 3j




print(type(age))
print(type(name))
print(type(flag))
print(type(number))
print(type(complex_num))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# ### Exercise
# Create variable for each name, age, live and GPA

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# # String variable for name
# name = "Hossam"
#
# # Integer variable for age
# age = 25
#
# # Float variable for GPA
# GPA = 3.75
#
# # String variable for Live
# live = "Tanta"
# ```
# </details>
#
# ```

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### Operations

# %%
1 + 1
# Out:
# 2

# %%
1 * 3
# Out:
# 3

# %%
1 / 2
# Out:
# 0.5

# %%
2 ** 4   #power
# Out:
# 16

# %%
1 % 2
# Out:
# 1

# %%
5 % 2
# Out:
# 1

# %%
(2 + 3) * (5 + 5)
# Out:
# 50

# %% [markdown]
# ### Variable Assignment

# %%
# Can not start with number or special characters
name_of_var = 2

# %%
x = 2
y = 3

# %%
z = x + y

# %%
z
# Out:
# 5

# %% [markdown]
# ### Exercise
# Create Equation y= (2x+3) + (9 - 5*x) - (x/3)     give x = 10 , 0 , -10

# %%
#x = int(input("Enter your number: "))

#print(x*10)

x= float(input("Enter float number: "))   # casting : conversion from one datatype into another

y = (2*x + 3) + (9-5*x) - (x/3)

print("the result is : ", y)
# Out:
# Enter float number: 50
# the result is :  -154.66666666666666

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# # Calculate y for x = 10
# x = 10
# y1 = (2 * x + 3) + (9 - 5 * x) - (x / 3)
# print(y1)
#
# # Calculate y for x = 0
# x = 0
# y2 = (2 * x + 3) + (9 - 5 * x) - (x / 3)
# print(y2)
#
# # Calculate y for x = -10
# x = -10
# y3 = (2 * x + 3) + (9 - 5 * x) - (x / 3)
# print(y3)
#
# ```

# %% [markdown]
# ### Strings

# %%
x='single quotes'

# %%
x="double quotes"

# %%
x = "Ahmed\nYousry\tAli"
print(x)
# Out:
# Ahmed
# Yousry	Ali

# %% [markdown]
# ### Exercise
# Create Variable with multi line
#
#  My name is Hossam.
#
#  Age 2.
#
#  Live in Tanta

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# data = """
#  My name is Hossam.
#  Age 25
#  Live in Tanta
# """
# print(data)
#
# ```
# </details>
#
# ```

# %% [markdown]
# ### Printing

# %%
x = 'hello'

# %%
x
# Out:
# 'hello'

# %%
print(x)
# Out:
# hello

# %%
num = 25
name = 'Hossam'

# %%
print('My number is: {one}, and my name is: {two}'.format(one=num,two=name))
# Out:
# My number is: 25, and my name is: Hossam

# %%
print('My number is: {}, and my name is: {}'.format(num,name))
# Out:
# My number is: 25, and my name is: Hossam

# %%
print(f'My number is: {num}, and my name is: {name}')
# Out:
# My number is: 25, and my name is: Hossam

# %%
print("My number is ", num,  "and my name is", name)
# Out:
# My number is  25 and my name is Hossam

# %% [markdown]
# ### Exercise
# Create Three Variable
#
# Name
#
# Age
#
# Live
#
# Factory
#
# then Print for each Way

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# Name = "Hossam"
# Age = 25
# Live =  "Tanta"
# Factory = "BFCAI"
# print(' My name is {one} \n my age is {two} \n live in {three} \n my Factory {four}'.format(one=Name,two=Age,three=Live,four=Factory))
# print(' My name is {} \n my age is {} \n live in {} \n my Factory {}'.format(Name,Age,Live,Factory))
# print(f' My name is {Name} \n my age is {Age} \n live in {Live} \n my Factory {Factory}')
# ```
# </details>
#
# ```

# %%
name = input("Enter your name : ")

print(name)
# Out:
# Enter your name : j
# j

# %%
number = float(input("Enter your number : "))

print(number*5.5)
# Out:
# Enter your number : 5
# 27.5

# %% [markdown]
# ### input

# %%
a=int(input('Enter number: '))
print(a)
print(a*5)
# Out:
# Enter number: 5
# 5
# 25

# %%
a=int(input('Enter number: '))
print(a)
print(type(a))
# Out:
# Enter number: 5
# 5
# <class 'int'>

# %%
a = '7.2' # string
print(float(a) * 50)
# Out:
# 360.0

# %%
a = '5'  #string
int(a)  #casting
# Out:
# 5

# %%
a = '5.6'
print(float(a) * 5)
# Out:
# 28.0

# %%
a = 10 #int
str(a)
# Out:
# '10'

# %%
int(float('5.5'))
# Out:
# 5

# %% [markdown]
# ### Exercise
# Take Value from user and convert it to integer and floating and string

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# V = input("Enter number")
# print(type(V))
# print(int(V))
# print(float(V))
# print(str(V))
# ```
# </details>
#
# ```

# %% [markdown]
# ### Lists

# %%
L= [1,2,3, 'a', 'Ahmed', True, 5.5]

print(L)
# Out:
# [1, 2, 3, 'a', 'Ahmed', True, 5.5]

# %%
l=[]  # l = list()

# %%
my_list = ['a','b','c']

# %%
my_list
# Out:
# ['a', 'b', 'c']

# %%
my_list[2]
# Out:
# 'c'

# %%
my_list[1]
# Out:
# 'b'

# %%
my_list[1:]
# Out:
# ['b', 'c']

# %%
my_list[:3]
# Out:
# ['a', 'b', 'c']

# %%
my_list[0] = 'NEW' # update the first value in the list

# %%
my_list
# Out:
# ['NEW', 'b', 'c']

# %%
nest = [1,    [1,10]    ,   3    ,  [4,5,['target', 10]]    ] # nested list

# %%
nest[3]
# Out:
# [4, 5, ['target', 10]]

# %%
nest[3][2]
# Out:
# ['target', 10]

# %%
nest[3][2][0]
# Out:
# 'target'

# %%
l1= [1,2,3]
l2=[7,8,9]
l3 = l1 + l2
l3
# Out:
# [1, 2, 3, 7, 8, 9]

# %%
len(l1)
# Out:
# 3

# %%
len(l3)
# Out:
# 6

# %%
my_list = ['a','b','c']

# %%
my_list.append('d')

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list.insert(2,50)

# %%
my_list
# Out:
# ['a', 'b', 50, 'c', 'd']

# %%
my_list.insert(3, 'Ahmed')

print(my_list)
# Out:
# ['a', 'b', 50, 'Ahmed', 'c', 'd']

# %%
my_list.extend([6,7,8])
my_list

#['a', 'b', 50, 'c', 'd', [6, 7, 8]] if you use append
# Out:
# ['a', 'b', 50, 'Ahmed', 'c', 'd', 6, 7, 8]

# %%
my_list.append([6,7,8])
my_list
# Out:
# ['a', 'b', 50, 'Ahmed', 'c', 'd', 6, 7, 8, [6, 7, 8]]

# %%
my_list
# Out:
# ['a', 'b', 50, 'Ahmed', 'c', 'd', 6, 7, 8, [6, 7, 8]]

# %%
my_list.pop(0)
# Out:
# 'a'

# %%
my_list
# Out:
# ['b', 50, 'Ahmed', 'c', 'd', 6, 7, 8, [6, 7, 8]]

# %%
my_list.pop(-1)
# Out:
# [6, 7, 8]

# %%
my_list
# Out:
# ['b', 50, 'Ahmed', 'c', 'd', 6, 7, 8]

# %%
my_list.pop(3)
# Out:
# 'c'

# %%
my_list
# Out:
# ['b', 50, 'Ahmed', 'd', 6, 7, 8]

# %%
my_list.remove(50)

# %%
my_list
# Out:
# ['b', 'Ahmed', 'd', 6, 7, 8]

# %%
my_list.index('b')
# Out:
# 0

# %%
lst=[1,2,3,4,4,90,1,4]

print(lst.count(4)) # how many four in the list
# Out:
# 3

# %%
lst=[3,10,0,-20]

# sort list
lst.sort()

print(lst)
# Out:
# [-20, 0, 3, 10]

# %%
my_list = [1, 2, 10, 4, 5]
# Reverse Using Slicing
reversed_lst=my_list[::-1]
print(reversed_lst)
# Out:
# [5, 4, 10, 2, 1]

# %%
L= [-20, 5, 2, 1]
L.sort()
print(L)
reversed_lst=L[::-1]
print(reversed_lst)
# Out:
# [-20, 1, 2, 5]
# [5, 2, 1, -20]

# %% [markdown]
# ### Exercise
#
# create empty list and add integer number and string and list of number and pop first and last element

# %%
# Out:
# List before popping: [25, 'Hello', [1, 2, 3]]
# Popped first element: 25
# Popped last element: [1, 2, 3]
# List after popping: ['Hello']

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# # Create an empty list
# my_list = []
#
# # Add an integer number
# my_list.append(25)
#
# # Add a string
# my_list.append("Hello")
#
# # Add a list of numbers
# my_list.append([1, 2, 3])
#
# # Print the list before popping
# print("List before popping:", my_list)
#
# # Pop the first element (index 0)
# first_element = my_list.pop(0)
# print("Popped first element:", first_element)
#
# # Pop the last element
# last_element = my_list.pop(-1)
# print("Popped last element:", last_element)
#
# # Print the list after popping
# print("List after popping:", my_list)
#
# ```
# </details>
#
# ```

# %% [markdown]
# ### Dictionaries

# %%
# dict({key:value})
z =dict({4:123} )
z
# Out:
# {4: 123}

# %%
{4:123}
# Out:
# {4: 123}

# %%
z[4]
# Out:
# 123

# %%
d = {'name':'Ahmed','age':'20', 'ID': 10 , 'Grade':'A'}

# %%
print(d)
# Out:
# {'name': 'Ahmed', 'age': '20', 'ID': 10, 'Grade': 'A'}

# %%
d['name']
# Out:
# 'Ahmed'

# %%
d['ID']
# Out:
# 10

# %%
d.keys()
# Out:
# dict_keys(['name', 'age', 'ID', 'Grade'])

# %%
d.values()
# Out:
# dict_values(['Ahmed', '20', 10, 'A'])

# %%
d.items()
# Out:
# dict_items([('name', 'Ahmed'), ('age', '20'), ('ID', 10), ('Grade', 'A')])

# %%
d['name']='Ali'   #update

# %%
d
# Out:
# {'name': 'Ali', 'age': '20', 'ID': 10, 'Grade': 'A'}

# %%
d['Address'] ="Cairo"   # Addition

# %%
d
# Out:
# {'name': 'Ali', 'age': '20', 'ID': 10, 'Grade': 'A', 'Address': 'Cairo'}

# %%
d.pop("ID")
# Out:
# 10

# %%
d
# Out:
# {'name': 'Ali', 'age': '20', 'Grade': 'A', 'Address': 'Cairo'}

# %%
d.popitem()
# Out:
# ('Address', 'Cairo')

# %%
d
# Out:
# {'name': 'Ali', 'age': '20', 'Grade': 'A'}

# %%
d.update({'name':'Youssef','phone':'0124444444'})

# %%
d
# Out:
# {'name': 'Youssef', 'age': '20', 'Grade': 'A', 'phone': '0124444444'}

# %%
d['address']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-934540997.py in <cell line: 0>()
# ----> 1 d['address']
#
# KeyError: 'address'

# %%
d.get('address')

# %% [markdown]
# ### Exercise
#
# Create a dictionary with at least four key-value pairs.
#
# update Value in dictionary
#
# Remove an item using the pop() method.
#
# Remove the last item using the popitem() method.

# %%
# Out:
# Original dictionary: {'name': 'Hossam', 'age': 25, 'GPA': 3.75, 'location': 'Tanta', 'major': 'Artificial Intelligence'}
# Dictionary after updating 'GPA': {'name': 'Hossam', 'age': 25, 'GPA': 3.9, 'location': 'Tanta', 'major': 'Artificial Intelligence'}
# Removed 'GPA': 3.9
# Dictionary after removing 'GPA': {'name': 'Hossam', 'age': 25, 'location': 'Tanta', 'major': 'Artificial Intelligence'}
# Removed last item: ('major', 'Artificial Intelligence')
# Dictionary after removing the last item: {'name': 'Hossam', 'age': 25, 'location': 'Tanta'}

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# # 1. Create a dictionary with at least four key-value pairs
# student = {
#     "name": "Hossam",
#     "age": 25,
#     "GPA": 3.75,
#     "location": "Tanta"
# }
#
# student['major'] = "Artificial Intelligence"
# # student.update({'major':"Artificial Intelligence"})
# print("Original dictionary:", student)
#
# # 2. Update the value of an existing key
# student["GPA"] = 3.9  # student.update({'GPA':10})
#
# print("Dictionary after updating 'GPA':", student)
#
# # 3. Remove an item using the `pop()` method
# removed_item = student.pop("GPA")
# print("Removed 'GPA':", removed_item)
# print("Dictionary after removing 'GPA':", student)
#
# # 4. Remove the last item using the `popitem()` method
# last_item = student.popitem()
# print("Removed last item:", last_item)
# print("Dictionary after removing the last item:", student)
#
#
# ```
# </details>
#
# ```

# %% [markdown]
# ### Tuples

# %%
t = tuple([1,2,3,4,5])

# %%
t
# Out:
# (1, 2, 3, 4, 5)

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 1

# %%
t[0] = 'NEW'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 t[0] = 'NEW'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count(5)
# Out:
# 1

# %%
t.index(1)
# Out:
# 0

# %%
t1=(1,2,3)
t2=(3,4,5)

t3=t1+t2

# %%
t1
# Out:
# (1, 2, 3)

# %%
t3
# Out:
# (1, 2, 3, 3, 4, 5)

# %% [markdown]
# ### Exercise

# %%
# Out:
# (1, 2, 3, 0) <class 'tuple'>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# t = tuple([1,2,3])
# t = list(t)
# t.append(0)
# t = tuple(t)
# print(t,type(t))
#
# ```
# </details>
#
# ```

# %% [markdown]
# Create a tuple named student_info that contains the following information: a student's name (as a string), their age (as an integer), and their GPA (as a float).
#
# Create another tuple more_info that contains the student's major (as a string) and their graduation year (as an integer). Concatenate student_info and more_info into a new tuple named full_info.
#
# add two tuple then count number of age

# %%
# Out:
# 21
# Hossam
# 21
# 3.9
# ('Hossam', 21, 3.9, 'Artificial Intelligence', 2024)
# 1

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# student_info = ("Hossam", 21, 3.9)
# print(student_info[1])  # Output: 21
#
# name, age, gpa = student_info
# print(name)  # Output: Hossam
# print(age)   # Output: 21
# print(gpa)   # Output: 3.9
#
# more_info = ("Artificial Intelligence", 2024)
# full_info = student_info + more_info
# print(full_info)  # Output: ('Hossam', 21, 3.9, 'Artificial Intelligence', 2024)
#
# print(full_info.count(21))  # Output: 1
#
# # Attempting to modify the tuple
# # student_info[0] = "Bob"  # This will raise a TypeError
# ```
# </details>
#
# ```

# %% [markdown]
# ### Sets

# %%
s=set([1,2,3])

# %%
s,type(s)
# Out:
# ({1, 2, 3}, set)

# %%
s = {1,2,3}

# %%
s
# Out:
# {1, 2, 3}

# %%
s.add(5)

# %%
s
# Out:
# {1, 2, 3, 5}

# %%
s.pop()
# Out:
# 1

# %%
l = [1,3,3,1,2,1,2,3,3,3,3,2,2,2,1,1,2]
type(l)
# Out:
# list

# %%
s=set(l)

# %%
s
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Exercise
#
# Create a set named fruits that contains the following items: "apple", "banana", "cherry".
#
# Add "orange" to the fruits set. Print the set to confirm the addition.
#
# Remove element

# %%
# Out:
# {'cherry', 'banana', 'apple'}
# {'cherry', 'orange', 'banana', 'apple'}
# cherry
# {'orange', 'banana', 'apple'}

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# fruits = {"apple", "banana", "cherry"}
# print(fruits)  # Output: {'apple', 'banana', 'cherry'}
#
# fruits.add("orange")
# print(fruits)  # Output: {'apple', 'banana', 'cherry', 'orange'}
#
# popped_element = fruits.pop()
# print(popped_element)  # Output: (an arbitrary element from the set)
# print(fruits)  # Output: (set after removal of the popped element)
#
# ```
# </details>
#
# ```

# %% [markdown]
# ## Comparison Operators

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
1 >= 1
# Out:
# True

# %%
1 <= 4
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
'hi' == 'bye'
# Out:
# False

# %% [markdown]
# ## Logic Operators

# %%
(1 > 2) and (2 < 3)
# Out:
# False

# %%
(1 > 2) or (2 < 3)
# Out:
# True

# %%
(1 == 2) or (2 == 3) or (4 == 4)
# Out:
# True

# %%
 1 != 2
# Out:
# True

# %% [markdown]
# ## if,elif, else Statements

# %%
x = int(input("Enter number: "))

# in C++
if (x==0){
    print("x==0")
    print("x==0")
    print("x==0")
    print("x==0")
}else{
    print("x!=0")
    print("x!=0")
    print("x!=0")
}
print("hello")

#in Python
if x==0:
    print("x==0")
    print("x==0")
    print("x==0")
    print("x==0")
else:
    print("x!=0")
    print("x!=0")
    print("x!=0")

print("hello")
# Out:
# Enter number: 5
# hello

# %%
num = int(input("Enter your number: "))

if num % 2 ==0:
  print("number is even")
else:
  print("number is odd")
# Out:
# Enter your number: 49
# number is odd

# %%
num = int(input("Enter your number: "))
if num > 0:
  print("number is positive")
elif num < 0:
  print("number is negative")
else:
  print("number is zero")
# Out:
# Enter your number: 0
# number is zero

# %%
if 1 > 2:
    print('yep!')

# %%
if 1 < 2:
    print('first')
else:
    print('last')
# Out:
# first

# %%
if 3 > 2:
    print('first')
    print("hello")
else:
    print('last')
# Out:
# first
# hello

# %%
if 1 == 2:
    print('first')
elif 3 == 3:
    print('middle')
else:
    print('Last')
# Out:
# middle

# %%
if 3 in [1,2,3,4,5]:
    print('Yes')
else :
    print('NO')
# Out:
# Yes

# %%
if 3 not in [1,2,3,4,5]:
    print('Yes')
else :
    print('NO')
# Out:
# NO

# %%
#Examples
grade=70

if grade >= 70:
    print("pass")
else:
    print('fail')

##############################
if 90<= grade <=100:
    print('A')
elif grade<90 and grade>=80:
    print("B")
elif  70<=grade<80:
    print("C")
elif 0<=grade<70:
    print("Fail")
else:
    print("Invalid grade")
# Out:
# pass
# C

# %% [markdown]
# ### Exercise
#
# Takes a number input from the user, checks if the number is even or odd, and performs additional checks based on that:

# %%
x = int (input("Enter your number: "))
if x % 2 == 0 :
  print("Even")
else:
  print("Odd")
# Out:
# Enter your number: 20
# Even

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# # Take input from the user
# number = int(input("Enter a number: "))
#
# # Check if the number is even or odd
# if number % 2 == 0:
#     # If the number is even, check if it's greater than 10 or less
#     if number > 10:
#         print(f"The number {number} is even and greater than 10.")
#     else:
#         print(f"The number {number} is even and less than or equal to 10.")
# else:
#     # If the number is odd, print its value
#     print(f"The number {number} is odd.")
#
# ```
# </details>
#
# ```

# %% [markdown]
# # Great Job!
