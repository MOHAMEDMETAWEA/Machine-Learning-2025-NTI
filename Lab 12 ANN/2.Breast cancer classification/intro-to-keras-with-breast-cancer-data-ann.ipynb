# %% [markdown]
# https://www.kaggle.com/code/thebrownviking20/intro-to-keras-with-breast-cancer-data-ann/notebook

# %% [markdown]
# # Aim
# This is a small yet useful kernel for providing an introduction to **Artificial Neural Networks** for people who want to begin their journey into the field of **deep learning**. For this, I have used Keras which is a high-level Neural Networks API built on top of low level neural networks APIs like Tensorflow and Theano. As it is high-level, many things are already taken care of therefore it is easy to work with and a great tool to start with. [Here's the documentation for keras](https://keras.io/)
#
# # What is Deep learning?
# Deep Learning is a subfield of machine learning concerned with algorithms inspired by the structure and function of the brain called artificial neural networks. Deep learning is a machine learning technique that teaches computers to do what comes naturally to humans: learn by example. Deep learning is a key technology behind driverless cars, enabling them to recognize a stop sign, or to distinguish a pedestrian from a lamppost. It is the key to voice control in consumer devices like phones, tablets, TVs, and hands-free speakers. Deep learning is getting lots of attention lately and for good reason. It’s achieving results that were not possible before.
#
#
# # What are artificial neural networks?
# An artificial neuron network (ANN) is a computational model based on the structure and functions of biological neural networks. Information that flows through the network affects the structure of the ANN because a neural network changes - or learns, in a sense - based on that input and output. ANNs are considered nonlinear statistical data modeling tools where the complex relationships between inputs and outputs are modeled or patterns are found. ANN is also known as a neural network.

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/1000/1*ZX05x1xYgaVoa4Vn2kKS9g.png">

# %% [markdown]
# A single neuron is known as a perceptron. It consists of a layer of inputs(corresponds to columns of a dataframe). Each input has a weight which controls the magnitude of an input.
# The summation of the products of these input values and weights is fed to the activation function. Activation functions are really important for a Artificial Neural Network to learn and make sense of something really complicated and Non-linear complex functional mappings between the inputs and response variable.
#
# They introduce non-linear properties to our Network.Their main purpose is to convert a input signal of a node in a A-NN to an output signal. That output signal now is used as a input in the next layer in the stack.  Specifically in A-NN we do the sum of products of inputs(X) and their corresponding Weights(W) and apply a Activation function f(x) to it to get the output of that layer and feed it as an input to the next layer. [Refer to this article for more info.](https://towardsdatascience.com/activation-functions-and-its-types-which-is-better-a9a5310cc8f)
# <img src="https://cdnpythonmachinelearning.azureedge.net/wp-content/uploads/2017/09/Single-Perceptron.png">
# **Concept of backpropagation** - Backpropagation, short for "backward propagation of errors," is an algorithm for supervised learning of artificial neural networks using gradient descent. Given an artificial neural network and an error function, the method calculates the gradient of the error function with respect to the neural network's weights. It is a generalization of the delta rule for perceptrons to multilayer feedforward neural networks.
# <img src="https://www.researchgate.net/profile/Hassan_Al-Haj_Ibrahim/publication/235338024/figure/fig6/AS:299794191929349@1448487913220/Flow-chart-for-the-back-propagation-BP-learning-algorithm.png">
# **Gradient Descent** - To explain Gradient Descent I’ll use the classic mountaineering example. Suppose you are at the top of a mountain, and you have to reach a lake which is at the lowest point of the mountain (a.k.a valley). A twist is that you are blindfolded and you have zero visibility to see where you are headed. So, what approach will you take to reach the lake? The best way is to check the ground near you and observe where the land tends to descend. This will give an idea in what direction you should take your first step. If you follow the descending path, it is very likely you would reach the lake. [Refer to this article for more information.](https://www.analyticsvidhya.com/blog/2017/03/introduction-to-gradient-descent-algorithm-along-its-variants/)

# %% [markdown]
# About Breast Cancer Wisconsin (Diagnostic) Data Set
# Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass. They describe characteristics of the cell nuclei present in the image. n the 3-dimensional space is that described in: [K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server: ftp ftp.cs.wisc.edu cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# Also can be found on UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29
#
# Attribute Information:
#
# 1) ID number 2) Diagnosis (M = malignant, B = benign) 3-32)
#
# Ten real-valued features are computed for each cell nucleus:
#
# a) radius (mean of distances from center to points on the perimeter) b) texture (standard deviation of gray-scale values) c) perimeter d) area e) smoothness (local variation in radius lengths) f) compactness (perimeter^2 / area - 1.0) g) concavity (severity of concave portions of the contour) h) concave points (number of concave portions of the contour) i) symmetry j) fractal dimension ("coastline approximation" - 1)
#
# The mean, standard error and "worst" or largest (mean of the three largest values) of these features were computed for each image, resulting in 30 features. For instance, field 3 is Mean Radius, field 13 is Radius SE, field 23 is Worst Radius.
#
# All feature values are recoded with four significant digits.
#
# Missing attribute values: none
#
# Class distribution: 357 benign, 212 malignant

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Machine learning 2024/Notebooks - ANN - DNN/2.Breast cancer classification
# Out:
# /content/drive/MyDrive/Machine learning 2024/Notebooks - ANN - DNN/2.Breast cancer classification

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Importing data
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
del data['Unnamed: 32']

# %%
X = data.iloc[:, 2:].values
y = data.iloc[:, 1].values

# Encoding categorical data
from sklearn.preprocessing import LabelEncoder
labelencoder_X_1 = LabelEncoder()
y = labelencoder_X_1.fit_transform(y)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (512, 30)

# %% [markdown]
# **Now that we have prepared data, we will import Keras and its packages.**

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
# Need Dense layers for this task of breast cancer
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 30))
# Adding dropout to prevent overfitting
classifier.add(Dropout(rate = 0.1))

# Adding the second hidden layer
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
# Adding dropout to prevent overfitting
classifier.add(Dropout(rate = 0.1))

# Adding the second hidden layer
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
# Adding dropout to prevent overfitting
classifier.add(Dropout(rate = 0.1))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))  # 0 - 1   >=0.5 ? 1 , 0
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
classifier.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             272 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,057 (4.13 KB)
#  Trainable params: 1,057 (4.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# input_dim - number of columns of the dataset
#
# output_dim - number of outputs to be fed to the next layer, if any
#
# activation - activation function which is ReLU in this case
#
# init - the way in which weights should be provided to an ANN
#
# When you use **kernel_initializer='uniform'**, it means that the weights of the layer are initialized by drawing random values from a uniform distribution. Specifically, the weights are initialized with values from a uniform distribution within a specific

# %% [markdown]
# output_dim is 1 as we want only 1 output from the final layer.
#
# Sigmoid function is used when dealing with classfication problems with 2 types of results.(Submax function is used for 3 or more classification results)
# <img src="https://cdn-images-1.medium.com/max/1000/1*Xu7B5y9gp0iL5ooBj7LtWw.png">

# %%
# Compiling the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Optimizer is chosen as adam for gradient descent.
#
# Binary_crossentropy is the loss function used.
#
# Cross-entropy loss, or log loss, measures the performance of a classification model whose output is a probability value between 0 and 1. Cross-entropy loss increases as the predicted probability diverges from the actual label. So predicting a probability of .012 when the actual observation label is 1 would be bad and result in a high loss value. A perfect model would have a log loss of 0. [More about this](http://ml-cheatsheet.readthedocs.io/en/latest/loss_functions.html)

# %%
# Fitting the ANN to the Training set
history=classifier.fit(X_train, y_train,validation_split=0.2, batch_size=64, epochs=150)
# Long scroll ahead but worth
# The batch size and number of epochs have been set using trial and error. Still looking for more efficient ways. Open to suggestions.
# Out:
# Epoch 1/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - accuracy: 0.5650 - loss: 0.6925 - val_accuracy: 0.6019 - val_loss: 0.6901
# Epoch 2/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6544 - loss: 0.6883 - val_accuracy: 0.6117 - val_loss: 0.6840
# Epoch 3/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6347 - loss: 0.6810 - val_accuracy: 0.6990 - val_loss: 0.6714
# Epoch 4/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7558 - loss: 0.6642 - val_accuracy: 0.8738 - val_loss: 0.6480
# Epoch 5/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8804 - loss: 0.6360 - val_accuracy: 0.9223 - val_loss: 0.6095
# Epoch 6/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9139 - loss: 0.5956 - val_accuracy: 0.9515 - val_loss: 0.5538
# Epoch 7/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9206 - loss: 0.5290 - val_accuracy: 0.9612 - val_loss: 0.4824
# Epoch 8/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9184 - loss: 0.4564 - val_accuracy: 0.9709 - val_loss: 0.4056
# Epoch 9/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9382 - loss: 0.3738 - val_accuracy: 0.9709 - val_loss: 0.3332
# Epoch 10/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9364 - loss: 0.3126 - val_accuracy: 0.9806 - val_loss: 0.2729
# Epoch 11/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9287 - loss: 0.2740 - val_accuracy: 0.9806 - val_loss: 0.2254
# Epoch 12/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9408 - loss: 0.2213 - val_accuracy: 0.9806 - val_loss: 0.1873
# Epoch 13/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9561 - loss: 0.1932 - val_accuracy: 0.9806 - val_loss: 0.1581
# Epoch 14/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9548 - loss: 0.1548 - val_accuracy: 0.9903 - val_loss: 0.1367
# Epoch 15/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9590 - loss: 0.1459 - val_accuracy: 0.9903 - val_loss: 0.1217
# Epoch 16/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9521 - loss: 0.1546 - val_accuracy: 0.9903 - val_loss: 0.1113
# Epoch 17/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9725 - loss: 0.1121 - val_accuracy: 0.9806 - val_loss: 0.1008
# Epoch 18/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9580 - loss: 0.1332 - val_accuracy: 0.9806 - val_loss: 0.0925
# Epoch 19/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9561 - loss: 0.1320 - val_accuracy: 0.9806 - val_loss: 0.0851
# Epoch 20/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9777 - loss: 0.0978 - val_accuracy: 0.9806 - val_loss: 0.0785
# Epoch 21/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9619 - loss: 0.1164 - val_accuracy: 0.9806 - val_loss: 0.0746
# Epoch 22/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9712 - loss: 0.0961 - val_accuracy: 0.9806 - val_loss: 0.0704
# Epoch 23/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9758 - loss: 0.0908 - val_accuracy: 0.9806 - val_loss: 0.0665
# Epoch 24/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9849 - loss: 0.0857 - val_accuracy: 0.9806 - val_loss: 0.0642
# Epoch 25/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9805 - loss: 0.0861 - val_accuracy: 0.9806 - val_loss: 0.0616
# Epoch 26/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9853 - loss: 0.0805 - val_accuracy: 0.9806 - val_loss: 0.0586
# Epoch 27/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9774 - loss: 0.0866 - val_accuracy: 0.9806 - val_loss: 0.0565
# Epoch 28/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9761 - loss: 0.0955 - val_accuracy: 0.9806 - val_loss: 0.0539
# Epoch 29/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9707 - loss: 0.0965 - val_accuracy: 0.9806 - val_loss: 0.0514
# Epoch 30/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9860 - loss: 0.0696 - val_accuracy: 0.9806 - val_loss: 0.0495
# Epoch 31/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9824 - loss: 0.0723 - val_accuracy: 0.9806 - val_loss: 0.0480
# Epoch 32/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9728 - loss: 0.0929 - val_accuracy: 0.9903 - val_loss: 0.0467
# Epoch 33/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9749 - loss: 0.0744 - val_accuracy: 0.9903 - val_loss: 0.0452
# Epoch 34/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9850 - loss: 0.0691 - val_accuracy: 0.9903 - val_loss: 0.0451
# Epoch 35/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9829 - loss: 0.0720 - val_accuracy: 0.9903 - val_loss: 0.0442
# Epoch 36/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9786 - loss: 0.0706 - val_accuracy: 0.9903 - val_loss: 0.0429
# Epoch 37/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9826 - loss: 0.0693 - val_accuracy: 0.9903 - val_loss: 0.0419
# Epoch 38/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9759 - loss: 0.0742 - val_accuracy: 0.9903 - val_loss: 0.0408
# Epoch 39/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9851 - loss: 0.0599 - val_accuracy: 0.9903 - val_loss: 0.0396
# Epoch 40/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9748 - loss: 0.0903 - val_accuracy: 0.9903 - val_loss: 0.0387
# Epoch 41/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9784 - loss: 0.0702 - val_accuracy: 0.9903 - val_loss: 0.0378
# Epoch 42/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9791 - loss: 0.0714 - val_accuracy: 0.9903 - val_loss: 0.0372
# Epoch 43/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9857 - loss: 0.0511 - val_accuracy: 0.9903 - val_loss: 0.0360
# Epoch 44/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9855 - loss: 0.0527 - val_accuracy: 0.9903 - val_loss: 0.0358
# Epoch 45/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9875 - loss: 0.0518 - val_accuracy: 0.9903 - val_loss: 0.0350
# Epoch 46/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9877 - loss: 0.0466 - val_accuracy: 0.9903 - val_loss: 0.0357
# Epoch 47/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9724 - loss: 0.0736 - val_accuracy: 0.9903 - val_loss: 0.0357
# Epoch 48/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9758 - loss: 0.0715 - val_accuracy: 0.9903 - val_loss: 0.0350
# Epoch 49/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9876 - loss: 0.0517 - val_accuracy: 0.9903 - val_loss: 0.0334
# Epoch 50/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9826 - loss: 0.0553 - val_accuracy: 0.9903 - val_loss: 0.0328
# Epoch 51/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9831 - loss: 0.0555 - val_accuracy: 0.9903 - val_loss: 0.0320
# Epoch 52/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9733 - loss: 0.0803 - val_accuracy: 0.9903 - val_loss: 0.0318
# Epoch 53/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9759 - loss: 0.0755 - val_accuracy: 0.9903 - val_loss: 0.0312
# Epoch 54/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9838 - loss: 0.0497 - val_accuracy: 0.9903 - val_loss: 0.0300
# Epoch 55/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9753 - loss: 0.0710 - val_accuracy: 0.9903 - val_loss: 0.0293
# Epoch 56/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9720 - loss: 0.0862 - val_accuracy: 0.9903 - val_loss: 0.0291
# Epoch 57/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9854 - loss: 0.0476 - val_accuracy: 0.9903 - val_loss: 0.0287
# Epoch 58/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9791 - loss: 0.0632 - val_accuracy: 0.9903 - val_loss: 0.0284
# Epoch 59/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9837 - loss: 0.0587 - val_accuracy: 0.9903 - val_loss: 0.0283
# Epoch 60/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9812 - loss: 0.0545 - val_accuracy: 0.9903 - val_loss: 0.0279
# Epoch 61/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9789 - loss: 0.0596 - val_accuracy: 0.9903 - val_loss: 0.0275
# Epoch 62/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9786 - loss: 0.0576 - val_accuracy: 0.9903 - val_loss: 0.0272
# Epoch 63/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9750 - loss: 0.0639 - val_accuracy: 0.9903 - val_loss: 0.0270
# Epoch 64/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9837 - loss: 0.0690 - val_accuracy: 0.9903 - val_loss: 0.0270
# Epoch 65/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9889 - loss: 0.0478 - val_accuracy: 0.9903 - val_loss: 0.0266
# Epoch 66/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9883 - loss: 0.0442 - val_accuracy: 0.9903 - val_loss: 0.0263
# Epoch 67/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9847 - loss: 0.0575 - val_accuracy: 0.9903 - val_loss: 0.0263
# Epoch 68/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9842 - loss: 0.0549 - val_accuracy: 0.9903 - val_loss: 0.0261
# Epoch 69/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9866 - loss: 0.0533 - val_accuracy: 0.9903 - val_loss: 0.0259
# Epoch 70/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9849 - loss: 0.0572 - val_accuracy: 0.9903 - val_loss: 0.0257
# Epoch 71/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9812 - loss: 0.0685 - val_accuracy: 0.9903 - val_loss: 0.0255
# Epoch 72/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9839 - loss: 0.0622 - val_accuracy: 0.9903 - val_loss: 0.0246
# Epoch 73/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9874 - loss: 0.0476 - val_accuracy: 0.9903 - val_loss: 0.0243
# Epoch 74/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9865 - loss: 0.0460 - val_accuracy: 0.9903 - val_loss: 0.0242
# Epoch 75/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9839 - loss: 0.0501 - val_accuracy: 0.9903 - val_loss: 0.0240
# Epoch 76/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9818 - loss: 0.0589 - val_accuracy: 0.9903 - val_loss: 0.0239
# Epoch 77/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9813 - loss: 0.0535 - val_accuracy: 0.9903 - val_loss: 0.0235
# Epoch 78/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9842 - loss: 0.0492 - val_accuracy: 0.9903 - val_loss: 0.0233
# Epoch 79/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9844 - loss: 0.0412 - val_accuracy: 0.9903 - val_loss: 0.0228
# Epoch 80/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9864 - loss: 0.0498 - val_accuracy: 0.9903 - val_loss: 0.0238
# Epoch 81/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9883 - loss: 0.0463 - val_accuracy: 0.9903 - val_loss: 0.0238
# Epoch 82/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9843 - loss: 0.0399 - val_accuracy: 0.9903 - val_loss: 0.0234
# Epoch 83/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9933 - loss: 0.0347 - val_accuracy: 0.9903 - val_loss: 0.0227
# Epoch 84/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9935 - loss: 0.0374 - val_accuracy: 1.0000 - val_loss: 0.0220
# Epoch 85/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9861 - loss: 0.0519 - val_accuracy: 1.0000 - val_loss: 0.0219
# Epoch 86/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9946 - loss: 0.0304 - val_accuracy: 1.0000 - val_loss: 0.0215
# Epoch 87/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9916 - loss: 0.0327 - val_accuracy: 1.0000 - val_loss: 0.0212
# Epoch 88/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9938 - loss: 0.0354 - val_accuracy: 1.0000 - val_loss: 0.0210
# Epoch 89/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9902 - loss: 0.0419 - val_accuracy: 0.9903 - val_loss: 0.0214
# Epoch 90/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9888 - loss: 0.0407 - val_accuracy: 0.9903 - val_loss: 0.0209
# Epoch 91/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9943 - loss: 0.0306 - val_accuracy: 1.0000 - val_loss: 0.0204
# Epoch 92/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9876 - loss: 0.0469 - val_accuracy: 0.9903 - val_loss: 0.0206
# Epoch 93/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9935 - loss: 0.0316 - val_accuracy: 0.9903 - val_loss: 0.0207
# Epoch 94/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9906 - loss: 0.0403 - val_accuracy: 1.0000 - val_loss: 0.0194
# Epoch 95/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9933 - loss: 0.0295 - val_accuracy: 1.0000 - val_loss: 0.0188
# Epoch 96/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9875 - loss: 0.0453 - val_accuracy: 1.0000 - val_loss: 0.0188
# Epoch 97/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9832 - loss: 0.0525 - val_accuracy: 1.0000 - val_loss: 0.0190
# Epoch 98/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9883 - loss: 0.0449 - val_accuracy: 0.9903 - val_loss: 0.0193
# Epoch 99/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9919 - loss: 0.0337 - val_accuracy: 0.9903 - val_loss: 0.0192
# Epoch 100/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9897 - loss: 0.0354 - val_accuracy: 1.0000 - val_loss: 0.0190
# Epoch 101/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9936 - loss: 0.0304 - val_accuracy: 0.9903 - val_loss: 0.0199
# Epoch 102/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9908 - loss: 0.0346 - val_accuracy: 0.9903 - val_loss: 0.0201
# Epoch 103/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9917 - loss: 0.0324 - val_accuracy: 0.9903 - val_loss: 0.0197
# Epoch 104/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9903 - loss: 0.0339 - val_accuracy: 0.9903 - val_loss: 0.0191
# Epoch 105/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9874 - loss: 0.0417 - val_accuracy: 0.9903 - val_loss: 0.0192
# Epoch 106/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9921 - loss: 0.0281 - val_accuracy: 0.9903 - val_loss: 0.0202
# Epoch 107/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9956 - loss: 0.0269 - val_accuracy: 0.9903 - val_loss: 0.0199
# Epoch 108/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9921 - loss: 0.0311 - val_accuracy: 0.9903 - val_loss: 0.0196
# Epoch 109/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9952 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 0.0172
# Epoch 110/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9917 - loss: 0.0348 - val_accuracy: 1.0000 - val_loss: 0.0174
# Epoch 111/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9933 - loss: 0.0268 - val_accuracy: 1.0000 - val_loss: 0.0176
# Epoch 112/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9940 - loss: 0.0273 - val_accuracy: 0.9903 - val_loss: 0.0184
# Epoch 113/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9916 - loss: 0.0332 - val_accuracy: 1.0000 - val_loss: 0.0180
# Epoch 114/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.0231 - val_accuracy: 1.0000 - val_loss: 0.0170
# Epoch 115/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 0.0165
# Epoch 116/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9936 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 0.0164
# Epoch 117/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9937 - loss: 0.0284 - val_accuracy: 1.0000 - val_loss: 0.0162
# Epoch 118/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9956 - loss: 0.0234 - val_accuracy: 1.0000 - val_loss: 0.0158
# Epoch 119/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9901 - loss: 0.0299 - val_accuracy: 1.0000 - val_loss: 0.0156
# Epoch 120/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0231 - val_accuracy: 1.0000 - val_loss: 0.0158
# Epoch 121/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9946 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 0.0157
# Epoch 122/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9952 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 0.0151
# Epoch 123/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9892 - loss: 0.0332 - val_accuracy: 1.0000 - val_loss: 0.0151
# Epoch 124/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9924 - loss: 0.0274 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 125/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9852 - loss: 0.0419 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 126/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9931 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 0.0139
# Epoch 127/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9910 - loss: 0.0282 - val_accuracy: 1.0000 - val_loss: 0.0144
# Epoch 128/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9925 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0144
# Epoch 129/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9874 - loss: 0.0339 - val_accuracy: 1.0000 - val_loss: 0.0138
# Epoch 130/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0213 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 131/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9954 - loss: 0.0183 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 132/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9930 - loss: 0.0232 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 133/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9940 - loss: 0.0226 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 134/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9937 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 135/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9934 - loss: 0.0243 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 136/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9953 - loss: 0.0176 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 137/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9892 - loss: 0.0267 - val_accuracy: 1.0000 - val_loss: 0.0132
# Epoch 138/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9957 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 139/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9930 - loss: 0.0213 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 140/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9966 - loss: 0.0147 - val_accuracy: 1.0000 - val_loss: 0.0124
# Epoch 141/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9928 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 142/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9968 - loss: 0.0161 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 143/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9918 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0122
# Epoch 144/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9963 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 145/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9962 - loss: 0.0152 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 146/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9961 - loss: 0.0136 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 147/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9930 - loss: 0.0201 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 148/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9913 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 149/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9940 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 150/150
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9917 - loss: 0.0235 - val_accuracy: 1.0000 - val_loss: 0.0111

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy']) # Access history from the 'history' object
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss']) # Access history from the 'history' object
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# Batch size defines number of samples that going to be propagated through the network.
#
# An Epoch is a complete pass through all the training data.

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)   # 0 - 1
y_pred = (y_pred >= 0.5)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
# Confusion matrix with blue colors wiyh 6*5 fig size

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, cmap="Blues", annot=True, fmt='g')
plt.show()

# %%
# Classification report

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        35
#            1     1.0000    1.0000    1.0000        22
#
#     accuracy                         1.0000        57
#    macro avg     1.0000    1.0000    1.0000        57
# weighted avg     1.0000    1.0000    1.0000        57
